# %%
import pandas as pd

pd.read_csv('gymy_V2.csv')
# Out:
#      Unnamed: 0                            names                   city  \
# 0             0             Futeca Gym - Zona 14  Guatemala - Guatemala
# 1             1  Futeca Gym - Pradera Concepción  Guatemala - Guatemala
# 2             2          Futeca Gym - Miraflores  Guatemala - Guatemala
# 3             3       Futeca Gym - San Cristóbal  Guatemala - Guatemala
# 4             4             Futeca Gym - Naranjo  Guatemala - Guatemala
# ..          ...                              ...                    ...
# 239         239                   Sense CrossFit  Guatemala - Guatemala
# 240         240                    AMSI CrossFit  Guatemala - Guatemala
# 241         241          Brau Athletics CrossFit  Guatemala - Guatemala
# 242         242        CrossFit Spring City Once  Guatemala - Guatemala
# 243         243        CrossFit Spring City Once  Guatemala - Guatemala
#
#                                                address  \
# ...
