# %%
import re
import requests
from bs4 import BeautifulSoup
import unidecode
import numpy as np
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from tqdm import tqdm
from tqdm import trange

# %% [markdown]
# # Obtención de información
#
# Each establishment will initially consist of following fields:
# - id
# - name
# - description
# - phone
# - website
# - hours
# - category
# - address
# - zip code
# - city
# - country
# - latitude
# - longitude

# %%
def get_yellow_info_improved(url,category):
    
    names=[]
    city=[]
    address=[]
    phone=[]
    web=[]
    description=[]
    
    response = requests.get(url)
    
    #get soup
    soup = BeautifulSoup(response.text,'lxml')
    
    #getting main box
    general = soup.find_all('div', itemtype="https://schema.org/LocalBusiness")

    
    if len(general)>0:
        for i in range(len(general)):

            #NAMES
            try:
                names.append(general[i].find('a', class_='companyName').text.split('\n')[1].strip())
            except:
                names.append(np.nan)

           #CITY
            try:
                city.append(general[i].find('span', class_='city').text.strip())
            except:
                city.append(np.nan)

            #Address
            try:
                address.append(general[i].find('span', class_='directionFig').text.split('\n')[1].strip())
            except:
                address.append(np.nan)


            #phone
            try:
                phone.append(general[i].find('span', class_='phoneFig hide').text.strip())
            except:
                phone.append(np.nan)

            #web
            try:
                web.append(general[i].find('a', class_='webLink').text.strip())

            except:
                web.append(np.nan)

            #description
            try:
                description.append(general[i].find('div', class_='col-sm-12 infoBox').text.strip())
            except:
                description.append(np.nan)
                
        
        #creating dataframe
        df = pd.DataFrame(zip(names, city, address,phone,web,description),
                              columns=['names','city','address','phone','web','description'])
        
        df['categoría'] = category
        
        return df
                
            
    else:
        return print('no se pudo, response:', response.status_code)

# %% [markdown]
# # First Batch

# %%
lista_url = [
        ['https://www.paginasamarillas.com.gt/servicios/gimnasios-de-educacion-fisica?page=1',
         'Gimnasios de educacion física'],
    
        ['https://www.paginasamarillas.com.gt/servicios/gimnasios-de-educacion-fisica?page=2',
         'Gimnasios de educacion física'],
    
        ['https://www.paginasamarillas.com.gt/servicios/gimnasios-de-educacion-fisica?page=3',
         'Gimnasios de educacion física'],
    
        ['https://www.paginasamarillas.com.gt/servicios/federaciones-deportivas',
         'federaciones deportivas'],
    
        ['https://www.paginasamarillas.com.gt/servicios/federaciones',
         'federaciones deportivas'],
    
        ['https://www.paginasamarillas.com.gt/servicios/academias-de-ballet', 
         'ballet'],
    
        ['https://www.paginasamarillas.com.gt/servicios/bolos',
         'boliche'],
    
        ['https://www.paginasamarillas.com.gt/servicios/artes-marciales-ensenanza-de',
         'artes marciales'],
    
        ['https://www.paginasamarillas.com.gt/servicios/deportes?page=1',
         'deportes'],
    
        ['https://www.paginasamarillas.com.gt/servicios/deportes?page=2',
         'deportes'],
    
        ['https://www.paginasamarillas.com.gt/servicios/deportes?page=3',
         'deportes'],
    
        ['https://www.paginasamarillas.com.gt/servicios/deportes?page=4',
         'deportes'],
    
        ['https://www.paginasamarillas.com.gt/servicios/entrenamiento-fisico',
         'entrenamiento fisico']
        ]

# %%
df = pd.DataFrame()

# %%
for url in lista_url:
    bucle = get_yellow_info_improved(url[0],url[1])
    df = pd.concat([df,bucle],ignore_index=True)

# %%
df.tail()
# Out:
#                                  names                   city  \
# 164  San Silvestre Spa Sauna Y Jacuzzi  Guatemala - Guatemala
# 165              Sporta Guatemala S.A.  Guatemala - Guatemala
# 166                       Vmedical Spa  Guatemala - Guatemala
# 167                              Fiore  Guatemala - Guatemala
# 168                Hostal Los Volcanes  Guatemala - Guatemala
#
#                                          address             phone  web  \
# 164  1 Av Cl A 4-64 Z 7 Almolonga Quetzaltenango  (+502) 7766 8587  NaN
# 165                 KM 18.5 CARRET A EL SALVADOR  (+502) 6625 9100  NaN
# 166         3 Cl A 8-38 Edif Renova Z 10 3 Nivel  (+502) 3006 3604  NaN
# 167              Av Americas 9-55 Plaza Oro L 10  (+502) 2366 7166  NaN
# 168               16 Calle 8-00 Zona 13 Aurora 1  (+502) 2360 3232  NaN
#
#     description             categoría
# 164              entrenamiento fisico
# 165              entrenamiento fisico
# 166              entrenamiento fisico
# 167              entrenamiento fisico
# 168              entrenamiento fisico

# %% [markdown]
# # Second Batch

# %%
lista_url2 = [
                ['https://www.paginasamarillas.com.gt/servicios/escuelas-de-artes-marciales',
                 'artes marciales'],

                ['https://www.paginasamarillas.com.gt/servicios/escuelas-de-karate',
                 'artes marciales'],

                ['https://www.paginasamarillas.com.gt/servicios/escuelas-de-natacion',
                 'natacion'],

                ['https://www.paginasamarillas.com.gt/servicios/escuelas-de-vuelo-libre',
                 'aviacion'],

                ['https://www.paginasamarillas.com.gt/servicios/escuelas-de-aviacion',
                 'aviacion'],

                ['https://www.paginasamarillas.com.gt/servicios/golf',
                 'golf'],

                ['https://www.paginasamarillas.com.gt/servicios/hipodromos',
                 'hipodromos']
                ]

# %%
df2 = pd.DataFrame()

# %%
for url in lista_url2:
    bucle = get_yellow_info_improved(url[0],url[1])
    df2 = pd.concat([df2,bucle],ignore_index=True)

# %%
df2
# Out:
#                                                 names  \
# 0                                     Cosenza Academy
# 1                                     Cosenza Academy
# 2                                  Schumann'S Cordova
# 3           Empresas De Competencia, Sociedad Anonima
# 4                                 Grupo Aquatic, S.A.
# 5                             Waterproof Swim Academy
# 6   Federacion Nacional De Natacion, Clavados, Pol...
# 7     Asociacion Nacional De Vuelo Libre De Guatemala
# 8                                         Gt Aviation
# 9                                    Golf Total, S.A.
# 10                                      Top Golf S.A.
# 11                                 Cubana De Aviacion
#
#                            city  \
# 0   San José Pinula - Guatemala
# 1   San José Pinula - Guatemala
# 2         Guatemala - Guatemala
# 3         Guatemala - Guatemala
# 4         Guatemala - Guatemala
# 5         Guatemala - Guatemala
# 6         Guatemala - Guatemala
# 7         Guatemala - Guatemala
# 8         Guatemala - Guatemala
# 9         Guatemala - Guatemala
# 10        Guatemala - Guatemala
# 11        Guatemala - Guatemala
#
#                                               address             phone  \
# 0   Km 18.9 Carretera A San José Pinula, C.C. la P...  (+502) 6637 5035
# 1   Km 18.9 Carretera A San José Pinula, C.C. la P...  (+502) 6637 5035
# 2   Blvd San Cristobal Centro Comercial San Cristo...  (+502) 2478 1097
# 3        Boulevard Rafael Landivar Paseo Cayala L 209  (+502) 2493 8000
# 4   Km 17.5 Boulevard San José Villa Nueva, Frente...  (+502) 2312 0808
# 5                          15 Av A y 3 Cl D Mixco Z 8  (+502) 2375 8195
# 6                                           10 Av Z-4  (+502) 2334 1075
# 7                10 Calle 2-28 Z 9 Casa de la Cultura  (+502) 2385 1221
# 8      Avenida Hincapié y 18 Calle Zona 13 Hangar K-2  (+502) 2458 4307
# 9                                    Av 30 Final Z.11  (+502) 2417 0000
# 10                                      7 Av 7-78 Z.4  (+502) 2360 7826
# 11              13 Cl 2Do Nivel Local 29 3-40 Zona 10  (+502) 2367 2288
#
#                                web  \
# 0           www.cosenzaacademy.com
# 1           www.cosenzaacademy.com
# 2   http://www.schumanscordova.com
# 3                              NaN
# 4       www.aquaticcenterguate.com
# 5                              NaN
# 6          http://www.fenadegua.gt
# 7            www.vuelolibre.com.gt
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
#
#                                           description        categoría
# 0   Buscamos poder contribuir a la formación integ...  artes marciales
# 1   Buscamos poder contribuir a la formación integ...  artes marciales
# 2                                                      artes marciales
# 3                                                      artes marciales
# 4   Clases de natación para bebés, niños y adultos...         natacion
# 5                                                             natacion
# 6                                                             natacion
# 7   Promover la práctica del vuelo libre como herr...         aviacion
# 8                                                             aviacion
# 9                                                                 golf
# 10                                                                golf
# 11                                                          hipodromos

# %%
df = pd.concat([df,df2], ignore_index=True)

# %%
df.shape
# Out:
# (181, 7)

# %%
df.head()
# Out:
#                   names                   city  \
# 0   Full Contact Studio  Guatemala - Guatemala
# 1  Club Atletico Atenas  Guatemala - Guatemala
# 2          Le Petit Spa  Guatemala - Guatemala
# 3            Madiel Spa  Guatemala - Guatemala
# 4      Armonia Colonial  Guatemala - Guatemala
#
#                                              address             phone  \
# 0                                      2 C 10-06 Z-1  (+502) 2232 6575
# 1                          Diagonal 14. 22-06 Zona 5  (+502) 2335 3680
# 2                                    Dg 6 14-86 Z 10  (+502) 2366 7508
# 3  Av las Americas 7-30 Z 13 Edif Real América L ...  (+502) 2360 5070
# 4  Boulevard Principal 23 Calle 18-96 Col. Villa ...  (+502) 2448 2553
#
#                            web description                      categoría
# 0                                           Gimnasios de educacion física
# 1    http://www.clubatenas.com              Gimnasios de educacion física
# 2  http://www.lepetitspagt.com              Gimnasios de educacion física
# 3   http://www.madielspa.es.tl              Gimnasios de educacion física
# 4                          NaN              Gimnasios de educacion física

# %%
baile('https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/scenic-dance-guatemala.html','baile description','webtest')
# Out:
#                     names                   city  \
# 0  Scenic Dance Guatemala  Guatemala - Guatemala
#
#                                              address                  phone  \
# 0  3a. avenida, 14-19 zona 14, Ciudad de Guatemal...  2368-0858 | 2478-4688
#
#        web                                        description  \
# 0  webtest  ¿Listo para aprender nuevos pasos? Scenic Danc...
#
#             category
# 0  baile description

# %%
url = 'https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/scenic-dance-guatemala.html'

# %%
def baile(url,category,web):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'lxml')
    names = [soup.find('h1').text]
    city = ['Guatemala - Guatemala']
    address = [soup.find('p',class_='address').text]
    phone = [soup.find('div',class_='schedule-box span_mobile12 span_tablet3 span3').text.strip().split('\n')[1]]
    description = [soup.find('div',class_='single-content').p.text.strip()]
    category = [category]
    web = [web]
    return pd.DataFrame(zip(names, city, address,phone,web,description,category),
                              columns=['names','city','address','phone','web','description','category'])

# %%
lista_url = [
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/scenic-dance-guatemala.html',
         'Baile','https://es-la.facebook.com/ScenicDance/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/salsa-latin-guatemala.html',
        'Baile','https://www.facebook.com/Salsa-Latin-Guatemala-178268719078/'],
        
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/academia-dance-art.html',
         'Baile','https://es-la.facebook.com/Danceartguatemala/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/academia-bellydance-rashida.html',
        'Baile', 'https://es-la.facebook.com/Rashidaacademy/'],
        
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/addiction-dance-studio.html',
        'Baile','https://es-la.facebook.com/adsgt/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/escuela-cubana-de-baile-.html',
        'Baile','https://es-la.facebook.com/Escuela-Cubana-de-Baile-110562958135/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/in-motion-dance-fitness-guatemala.html',
        'Baile','http://www.inmotiongt.com/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/academia-de-ballet-danzarte.html',
        'Baile','https://es-la.facebook.com/Danzarte.ballet/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/ritmo-y-sabor-guatemala.html',
        'Baile','https://es-la.facebook.com/ritmoysaborgt/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/escuela-municipal-de-danza-clasica.html',
        'Baile','https://es-la.facebook.com/EMDCgt/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/heroes-academy-guatemala-.html',
        'Baile','https://es-la.facebook.com/HeroesCompanyGT/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/unidanza-guatemala-.html',
        'Baile','http://unidanza.net/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/unlimited-dance-academy.html',
        'Baile','https://unlimited-dance.com.gt/'],
    
        ['https://www.guatemala.com/guias/pasatiempos/academias-de-baile-en-guatemala/the-dance-factory.html',
        'Baile','https://es-la.facebook.com/DanceFactoryGT/']
    

        ]

# %%
df=pd.DataFrame()
for url in lista_url:
    bucle = baile(url[0],url[1],url[2])
    df2 = pd.concat([df2,bucle],ignore_index=True)

# %%
df2
# Out:
#                                                 names  \
# 0                                     Cosenza Academy
# 1                                     Cosenza Academy
# 2                                  Schumann'S Cordova
# 3           Empresas De Competencia, Sociedad Anonima
# 4                                 Grupo Aquatic, S.A.
# 5                             Waterproof Swim Academy
# 6   Federacion Nacional De Natacion, Clavados, Pol...
# 7     Asociacion Nacional De Vuelo Libre De Guatemala
# 8                                         Gt Aviation
# 9                                    Golf Total, S.A.
# 10                                      Top Golf S.A.
# 11                                 Cubana De Aviacion
# 12                             Scenic Dance Guatemala
# 13                              Salsa Latin Guatemala
# 14                                 Academia Dance Art
# 15                        Academia BellyDance Rashida
# 16                             Addiction Dance Studio
# 17                            Escuela Cubana de Baile
# 18                In Motion Dance & Fitness Guatemala
# 19                        Academia de Ballet DanzArte
# 20                            Ritmo y Sabor Guatemala
# 21                 Escuela Municipal de Danza Clásica
# 22                           Heroes Academy Guatemala
# 23                                 Unidanza Guatemala
# 24                            Unlimited Dance Academy
# 25                                  The Dance Factory
#
#                            city  \
# 0   San José Pinula - Guatemala
# 1   San José Pinula - Guatemala
# 2         Guatemala - Guatemala
# 3         Guatemala - Guatemala
# 4         Guatemala - Guatemala
# 5         Guatemala - Guatemala
# 6         Guatemala - Guatemala
# 7         Guatemala - Guatemala
# 8         Guatemala - Guatemala
# 9         Guatemala - Guatemala
# 10        Guatemala - Guatemala
# 11        Guatemala - Guatemala
# 12        Guatemala - Guatemala
# 13        Guatemala - Guatemala
# 14        Guatemala - Guatemala
# 15        Guatemala - Guatemala
# 16        Guatemala - Guatemala
# 17        Guatemala - Guatemala
# 18        Guatemala - Guatemala
# 19        Guatemala - Guatemala
# 20        Guatemala - Guatemala
# 21        Guatemala - Guatemala
# 22        Guatemala - Guatemala
# 23        Guatemala - Guatemala
# 24        Guatemala - Guatemala
# 25        Guatemala - Guatemala
#
#                                               address                  phone  \
# 0   Km 18.9 Carretera A San José Pinula, C.C. la P...       (+502) 6637 5035
# 1   Km 18.9 Carretera A San José Pinula, C.C. la P...       (+502) 6637 5035
# 2   Blvd San Cristobal Centro Comercial San Cristo...       (+502) 2478 1097
# 3        Boulevard Rafael Landivar Paseo Cayala L 209       (+502) 2493 8000
# 4   Km 17.5 Boulevard San José Villa Nueva, Frente...       (+502) 2312 0808
# 5                          15 Av A y 3 Cl D Mixco Z 8       (+502) 2375 8195
# 6                                           10 Av Z-4       (+502) 2334 1075
# 7                10 Calle 2-28 Z 9 Casa de la Cultura       (+502) 2385 1221
# 8      Avenida Hincapié y 18 Calle Zona 13 Hangar K-2       (+502) 2458 4307
# 9                                    Av 30 Final Z.11       (+502) 2417 0000
# 10                                      7 Av 7-78 Z.4       (+502) 2360 7826
# 11              13 Cl 2Do Nivel Local 29 3-40 Zona 10       (+502) 2367 2288
# 12  3a. avenida, 14-19 zona 14, Ciudad de Guatemal...  2368-0858 | 2478-4688
# 13  18 calle 15-51, Zona 13 C.C. Paseo Real, Ciuda...  4217-2567 | 4008-6112
# 14  Bulevar Vista Hermosa 25-80, zona 15 Vista Her...              3093-8434
# 15  Plaza Las Cañas, Local 201, zona 10, Ciudad de...              2337-0980
# 16  Galerías Primma Locales 203 y 204, Ciudad de G...              5466-3773
# 17  Bulevar Vista Hermosa 2a. calle 14-85 zona 15,...              2369-5571
# 18  8a. Calle 28-00, zona 11 interior Parque Comer...              4226-3000
# 19  Avenida Elena 3-31 zona 1, Ciudad de Guatemala...              4662-6874
# 20  4a. avenida, 16-24 zona 14, Ciudad de Guatemal...              4800-2015
# 21  7a. avenida 11-67 zona 1, 2o. Nivel, Ciudad de...              2251-1898
# 22  6a. avenida 3-39 zona 1, Ciudad de Guatemala V...              5132-2501
# 23  Cardales de Cayalá Zona 16 Local 207 Sur, Diag...              2491-4337
# 24  Bulevar Los Próceres, 24-24 zona 10 C. C. Las ...  2366-7892 | 2366-7893
# 25  Km. 14.5 Carretera a El Salvador, Centro Comer...  6634-2230 | 2258-8628
#
#                                                   web  \
# 0                              www.cosenzaacademy.com
# 1                              www.cosenzaacademy.com
# 2                      http://www.schumanscordova.com
# 3                                                 NaN
# 4                          www.aquaticcenterguate.com
# 5                                                 NaN
# 6                             http://www.fenadegua.gt
# 7                               www.vuelolibre.com.gt
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12            https://es-la.facebook.com/ScenicDance/
# 13  https://www.facebook.com/Salsa-Latin-Guatemala...
# 14      https://es-la.facebook.com/Danceartguatemala/
# 15         https://es-la.facebook.com/Rashidaacademy/
# 16                  https://es-la.facebook.com/adsgt/
# 17  https://es-la.facebook.com/Escuela-Cubana-de-B...
# 18                         http://www.inmotiongt.com/
# 19        https://es-la.facebook.com/Danzarte.ballet/
# 20          https://es-la.facebook.com/ritmoysaborgt/
# 21                 https://es-la.facebook.com/EMDCgt/
# 22        https://es-la.facebook.com/HeroesCompanyGT/
# 23                               http://unidanza.net/
# 24                    https://unlimited-dance.com.gt/
# 25         https://es-la.facebook.com/DanceFactoryGT/
#
#                                           description        categoría  \
# 0   Buscamos poder contribuir a la formación integ...  artes marciales
# 1   Buscamos poder contribuir a la formación integ...  artes marciales
# 2                                                      artes marciales
# 3                                                      artes marciales
# 4   Clases de natación para bebés, niños y adultos...         natacion
# 5                                                             natacion
# 6                                                             natacion
# 7   Promover la práctica del vuelo libre como herr...         aviacion
# 8                                                             aviacion
# 9                                                                 golf
# 10                                                                golf
# 11                                                          hipodromos
# 12  ¿Listo para aprender nuevos pasos? Scenic Danc...              NaN
# 13  ¡Atención amantes del baile! Salsa Latin Guate...              NaN
# 14  La Academia Dance Art ofrece profesionales exp...              NaN
# 15  Esta academia de baile es ideal para las perso...              NaN
# 16  ¿Con ganas de bailar? Addiction Dance Studio e...              NaN
# 17  La Escuela Cubana de Baile es un espacio perfe...              NaN
# 18  In Motion Dance & Fitness es un centro muy com...              NaN
# 19  La Academia de Ballet DanzArte cuenta con tres...              NaN
# 20  Ritmo y Sabor es una reconocida academia en do...              NaN
# 21  ¿Amante de la música clásica? En la zona 1 de ...              NaN
# 22  Heroes Academy es una academia especializada y...              NaN
# 23  En Unidanza vas a encontrar un gran equipo de ...              NaN
# 24  ¿Con ganas de aprender pasos nuevos? Sin duda ...              NaN
# 25  The Dance Factory es una de las academias de b...              NaN
#
#    category
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12    Baile
# 13    Baile
# 14    Baile
# 15    Baile
# 16    Baile
# 17    Baile
# 18    Baile
# 19    Baile
# 20    Baile
# 21    Baile
# 22    Baile
# 23    Baile
# 24    Baile
# 25    Baile

# %% [markdown]
# # Crossfit

# %%
url = 'https://www.guatemala.com/deportes/crossfit/gimnasios-box-para-hacer-crossfit-guatemala.html'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text,'lxml')

# %%
names = [soup.find_all('h3')[i].text for i in range(len(soup.find_all('h3'))-2)]
names.insert(2,'CrossFit 502')
names.insert(4,'Crossfit FD6')
names.insert(9,'CrossFit Spring City Once')
names
# Out:
# ['Invictus Performance Training',
#  'CrossFit 502',
#  'CrossFit 502',
#  'CrossFit FD6',
#  'Crossfit FD6',
#  'Sense CrossFit',
#  'AMSI CrossFit',
#  'Brau Athletics CrossFit',
#  'CrossFit Spring City Once',
#  'CrossFit Spring City Once',
#  'Oaks CrossFit']

# %%
address = [soup.find_all('ul')[i].li.text.strip() for i in range(2,len(soup.find_all('ul'))-3)]
address
# Out:
# ['Ubicación: 8a. avenida 6-63, Zona 14',
#  'Ubicación:\xa0 Dinamia Cayalá, Zona 16 | C.C. Escala, Carretera a El Salvador',
#  'Ubicación: Plaza Futeca, Zona 14 | C.C. Miraflores, Zona 11',
#  'Ubicación:\xa09a. avenida 16-03, Zona 10',
#  'Ubicación: 8a. avenida, 9-28, San Cristóbal, Zona 8 de Mixco',
#  'Ubicación: Plaza Empresarial Muxbal, Santa Catarina Pinula',
#  'Ubicación: C.C. Via Majadas, Zona 11 | Expobodegas Petapa, Zona 12',
#  'Ubicación: Km. 19 Carretera a San José Pinula, San José Pinula']

# %%
address.insert(1,address[1].split('|')[0])
address[2] = address[2].split('|')[1]
address.insert(3,address[3].split('|')[0])
address[4] = address[4].split('|')[1]
address.insert(8,address[8].split('|')[0])
address[9] = address[9].split('|')[1]
address
# Out:
# ['Ubicación: 8a. avenida 6-63, Zona 14',
#  'Ubicación:\xa0 Dinamia Cayalá, Zona 16 ',
#  ' C.C. Escala, Carretera a El Salvador',
#  'Ubicación: Plaza Futeca, Zona 14 ',
#  ' C.C. Miraflores, Zona 11',
#  'Ubicación:\xa09a. avenida 16-03, Zona 10',
#  'Ubicación: 8a. avenida, 9-28, San Cristóbal, Zona 8 de Mixco',
#  'Ubicación: Plaza Empresarial Muxbal, Santa Catarina Pinula',
#  'Ubicación: C.C. Via Majadas, Zona 11 ',
#  ' Expobodegas Petapa, Zona 12',
#  'Ubicación: Km. 19 Carretera a San José Pinula, San José Pinula']

# %%
phone = [soup.find_all('ul')[i].find_all('li')[1].text.strip().split('Contacto:')[1].split('Facebook')[0].strip() for i in range(2,len(soup.find_all('ul'))-3)]
phone.insert(1,phone[1].split('|')[0])
phone[2] = phone[2].split('|')[1]
phone.insert(3,phone[3].split('|')[0])
phone[4] = phone[4].split('|')[1]
phone.insert(8,phone[8].split('|')[0])
phone[9] = phone[9].split('|')[1]
phone
# Out:
# ['2367 1239 |',
#  '2368 5013 en Dinamia Cayalá ',
#  ' 6637 3778 en Escala ',
#  '2213 6900 en Plaza Futeca ',
#  ' 2225 3200 en Miraflores ',
#  '2366 5836 |',
#  '2480 1592 |',
#  '2441 9008 |',
#  '2473 7396 en Majadas ',
#  ' 2477 4632 en Petapa ',
#  '6626 6576 |']

# %%
soup.find_all('a', href=True)[72]['href']
# Out:
# 'https://www.facebook.com/invictusperformance/'

# %%
web = [soup.find_all('a', href=True)[i]['href'] for i in range(72,79)]

# %%
web.insert(2,'https://www.facebook.com/CF502/')
web.insert(4,'https://www.facebook.com/d6lifechangingfitness/')
web.insert(9,'https://www.facebook.com/crossfitspringcity7/')

# %%
description = ['crossfit' for i in range(len(names))]
category = ['crossfit' for i in range(len(names))]
city = ['Guatemala - Guatemala' for i in range(len(names))]

# %%
category = ['crossfit' for i in range(len(names))]

# %%
city = ['Guatemala - Guatemala' for i in range(len(names))]

# %%
crossfit = pd.DataFrame(zip(names, city, address,phone,web,description,category),
                              columns=['names','city','address','phone','web','description','category'])

# %%
def numero(x): #si la fecha tiene formaro de dd-mmm-aa devuelve únicamente el año
    if re.search(r"(\d)", x.lower()):
        ye = re.search(r"^\d?\d-\w\w\w-(\d\d\d?\d?)$", x.lower())
        x = ye.group(1)
        return x
    else:
        return x

# %%
crossfit
# Out:
#                                              names                   city  \
# 0                    Invictus Performance Training  Guatemala - Guatemala
# 1                                     CrossFit 502  Guatemala - Guatemala
# 2                  https://www.facebook.com/CF502/  Guatemala - Guatemala
# 3                                     CrossFit 502  Guatemala - Guatemala
# 4  https://www.facebook.com/d6lifechangingfitness/  Guatemala - Guatemala
# 5                                     CrossFit FD6  Guatemala - Guatemala
# 6                                     Crossfit FD6  Guatemala - Guatemala
# 7                                   Sense CrossFit  Guatemala - Guatemala
# 8                                    AMSI CrossFit  Guatemala - Guatemala
# 9    https://www.facebook.com/crossfitspringcity7/  Guatemala - Guatemala
#
#                                              address  \
# 0               Ubicación: 8a. avenida 6-63, Zona 14
# 1               Ubicación:  Dinamia Cayalá, Zona 16
# 2               C.C. Escala, Carretera a El Salvador
# 3                  Ubicación: Plaza Futeca, Zona 14
# 4                           C.C. Miraflores, Zona 11
# 5              Ubicación: 9a. avenida 16-03, Zona 10
# 6  Ubicación: 8a. avenida, 9-28, San Cristóbal, Z...
# 7  Ubicación: Plaza Empresarial Muxbal, Santa Cat...
# 8              Ubicación: C.C. Via Majadas, Zona 11
# 9                        Expobodegas Petapa, Zona 12
#
#                           phone  \
# 0                   2367 1239 |
# 1  2368 5013 en Dinamia Cayalá
# 2          6637 3778 en Escala
# 3    2213 6900 en Plaza Futeca
# 4      2225 3200 en Miraflores
# 5                   2366 5836 |
# 6                   2480 1592 |
# 7                   2441 9008 |
# 8         2473 7396 en Majadas
# 9          2477 4632 en Petapa
#
#                                                web description  category
# 0    https://www.facebook.com/invictusperformance/    crossfit  crossfit
# 1                  https://www.facebook.com/CF502/    crossfit  crossfit
# 2                  https://www.facebook.com/CF502/    crossfit  crossfit
# 3  https://www.facebook.com/d6lifechangingfitness/    crossfit  crossfit
# 4  https://www.facebook.com/d6lifechangingfitness/    crossfit  crossfit
# 5           https://www.facebook.com/amsicrossfit/    crossfit  crossfit
# 6          https://www.facebook.com/brauathletics/    crossfit  crossfit
# 7    https://www.facebook.com/crossfitspringcity7/    crossfit  crossfit
# 8           https://www.facebook.com/OaksCrossFit/    crossfit  crossfit
# 9    https://www.facebook.com/crossfitspringcity7/    crossfit  crossfit

# %%
crossfit.phone = crossfit.phone.apply(lambda x: re.search(r"(\d+\s\d+)",x).group(1))

# %%
crossfit
# Out:
#                                              names                   city  \
# 0                    Invictus Performance Training  Guatemala - Guatemala
# 1                                     CrossFit 502  Guatemala - Guatemala
# 2                  https://www.facebook.com/CF502/  Guatemala - Guatemala
# 3                                     CrossFit 502  Guatemala - Guatemala
# 4  https://www.facebook.com/d6lifechangingfitness/  Guatemala - Guatemala
# 5                                     CrossFit FD6  Guatemala - Guatemala
# 6                                     Crossfit FD6  Guatemala - Guatemala
# 7                                   Sense CrossFit  Guatemala - Guatemala
# 8                                    AMSI CrossFit  Guatemala - Guatemala
# 9    https://www.facebook.com/crossfitspringcity7/  Guatemala - Guatemala
#
#                                              address      phone  \
# 0               Ubicación: 8a. avenida 6-63, Zona 14  2367 1239
# 1               Ubicación:  Dinamia Cayalá, Zona 16   2368 5013
# 2               C.C. Escala, Carretera a El Salvador  6637 3778
# 3                  Ubicación: Plaza Futeca, Zona 14   2213 6900
# 4                           C.C. Miraflores, Zona 11  2225 3200
# 5              Ubicación: 9a. avenida 16-03, Zona 10  2366 5836
# 6  Ubicación: 8a. avenida, 9-28, San Cristóbal, Z...  2480 1592
# 7  Ubicación: Plaza Empresarial Muxbal, Santa Cat...  2441 9008
# 8              Ubicación: C.C. Via Majadas, Zona 11   2473 7396
# 9                        Expobodegas Petapa, Zona 12  2477 4632
#
#                                                web description  category
# 0    https://www.facebook.com/invictusperformance/    crossfit  crossfit
# 1                  https://www.facebook.com/CF502/    crossfit  crossfit
# 2                  https://www.facebook.com/CF502/    crossfit  crossfit
# 3  https://www.facebook.com/d6lifechangingfitness/    crossfit  crossfit
# 4  https://www.facebook.com/d6lifechangingfitness/    crossfit  crossfit
# 5           https://www.facebook.com/amsicrossfit/    crossfit  crossfit
# 6          https://www.facebook.com/brauathletics/    crossfit  crossfit
# 7    https://www.facebook.com/crossfitspringcity7/    crossfit  crossfit
# 8           https://www.facebook.com/OaksCrossFit/    crossfit  crossfit
# 9    https://www.facebook.com/crossfitspringcity7/    crossfit  crossfit

# %%
url = 'https://dinamic.com.gt/forum-zona-10/'

response = requests.get(url)
soup = BeautifulSoup(response.text,'lxml')

# %%
names = soup.find('h2').text

# %%
city = ''

# %%
address = soup.find_all('h3')[0]

# %%
phone = soup.find_all('h3')[1]

# %%
web = 'https://dinamic.com.gt/'

# %%
description = 'Somos un nuevo tipo de gym, un lugar para ponerte en forma. ¡Un lugar para ser feliz!Nuestros programas de ejercicios están diseñados bajo una planificación de entrenamiento cardiovascular y de fuerza. Todo con un soporte científico que garantiza que obtendrás resultados de forma segura.'

# %%
category = 'Gimnasios de Educación Física'

# %%
def dinamic_fitness(url):
    names = [soup.find('h2').text]
    city = ['Guatemala - Guatemala']
    address = soup.find_all('h3')[0]
    phone = soup.find_all('h3')[1]
    web = ['https://dinamic.com.gt/']
    description = ['Somos un nuevo tipo de gym, un lugar para ponerte en forma. ¡Un lugar para ser feliz!Nuestros programas de ejercicios están diseñados bajo una planificación de entrenamiento cardiovascular y de fuerza. Todo con un soporte científico que garantiza que obtendrás resultados de forma segura.']
    category = ['Gimnasios de Educación Física']
    return pd.DataFrame(zip(names, city, address,phone,web,description,category),
                              columns=['names','city','address','phone','web','description','category'])

# %%
dinamic_fitness(url)
# Out:
#            names                   city  \
# 0  FORUM ZONA 10  Guatemala - Guatemala
#
#                                              address           phone  \
# 0  3ra ave 10-80 Zona 10 Edificio Forum Zona Viva...  TEL: 2214-0707
#
#                        web                                        description  \
# 0  https://dinamic.com.gt/  Somos un nuevo tipo de gym, un lugar para pone...
#
#                         category
# 0  Gimnasios de Educación Física

# %%
dinamic_fitness_url= ['https://dinamic.com.gt/naranjo/',
                      'https://dinamic.com.gt/forum-zona-10/',
                      'https://dinamic.com.gt/san-juan/',
                      'https://dinamic.com.gt/villa-hermosa/',
                      'https://dinamic.com.gt/portales/',
                      'https://dinamic.com.gt/roosevelt/']

# %%
len(soup.find_all('h3'))
# Out:
# 2

# %%
from selenium.webdriver.common.keys import Keys

# %%
html = driver.find_element_by_tag_name('html')
html.send_keys(Keys.END)
# Out:
# 'esto-es-un-test'

# %%
import time
scrap='https://directorio.guatemala.com/listado/guia/gimnasios/pagina/{}'.format(l)

soup = BeautifulSoup(response.text,'lxml')

# %%
paginas = [i for i in range(1,12)]

# %%
h2s=[]
for p in paginas:
    response = requests.get('https://directorio.guatemala.com/listado/guia/gimnasios/pagina/{}'.format(p))
    h2s.append(BeautifulSoup(response.text,'lxml').find_all('h2'))

# %%
h2s[0][0].text
# Out:
# 'Filtra tu búsqueda'

# %%
directorio = []
for h2 in h2s:
    for h in h2:
        directorio.append(h.text.strip())

# %%
directorio = set(directorio)
directorio = list(directorio)

# %%
len(directorio)
# Out:
# 101

# %%
from slugify import slugify
slug = [slugify(i) for i in directorio]

# %%
url = 'https://directorio.guatemala.com/listado/{}.html'.format(slug[0])
response = requests.get(url)
soup = BeautifulSoup(response.text,'lxml')

# %%
def gtcom(url):
    malos=[]
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'lxml')
    business = soup.find('div',class_='content-info-business')
    try:
        names = [business.find('h1').text]
    except:
        names = [np.nan]
        malos.append(sl)
    try:
        address = [business.find('span').text]
        city = ['Guatemala - Guatemala']
    except:
        address =[np.nan]
        city=[np.nan]
    try:
        phone = [soup.find('div',class_='business-buttons').find('a',href=True)['href']]
    except:
        phone=[np.nan]
    try:
        web = [soup.find('div',class_='business-buttons').find_all('a',href=True)[2]['href']]
    except:
        web=[np.nan]
    try:
        description = [soup.find('div',class_='info-description').text.strip().split('Sobre la empresa\n')[1].strip()]
    except:
        description =[np.nan]
    try:
        category = [soup.find('div',class_='business-categories').text.strip().split('Listado en: \n\n')[1].strip()]
    except:
        category=[np.nan]
    
    return pd.DataFrame(zip(names, city, address,phone,web,description,category),
                              columns=['names','city','address','phone','web','description','category'])

# %%
gt = pd.DataFrame()
for sl in slug:
    bucle = gtcom('https://directorio.guatemala.com/listado/{}.html'.format(sl))
    
    gt = pd.concat([gt,bucle],ignore_index=True)

# %%
gt.head()
# Out:
#                               names                   city  \
# 0                        Fight Club  Guatemala - Guatemala
# 1  CrossFit 502 Carr. a El Salvador  Guatemala - Guatemala
# 2                  Neurogym Antigua  Guatemala - Guatemala
# 3     Dinamic Fitness Zona Portales  Guatemala - Guatemala
# 4                               NaN                    NaN
#
#                                       address  \
# 0  24 ave 47-64 zona 12 Prados de Monte Maria
# 1            Km. 14.5 Carretera a El Salvador
# 2                       5a. Avenida Norte #17
# 3                   3a Avenida 10-10 Zona 17
# 4                                         NaN
#
#                              phone  \
# 0             tel:(5025) 4522-0530
# 1             tel:+(502) 6637-3778
# 2  tel:(502) 7831-5210 | 5892-2527
# 3             tel:+(502) 2217-1111
# 4                              NaN
#
#                                                  web  \
# 0  https://directorio.guatemala.com/listing_repor...
# 1  https://directorio.guatemala.com/listing_repor...
# 2  https://directorio.guatemala.com/listing_repor...
# 3  https://directorio.guatemala.com/listing_repor...
# 4                                                NaN
#
#                                          description  \
# 0  La cualidad dual de Fight Club Guatemala le de...
# 1  En CrossFit 502 nos enfocamos en que nuestros ...
# 2  Neurogym Antigua ofrece un programa de estimul...
# 3  Dinamic es un concepto nuevo de fitness, un lu...
# 4                                                NaN
#
#                                             category
# 0  Artes Marciales\n                             ...
# 1                                           Crossfit
# 2                                              Pesas
# 3                                              Pesas
# 4                                                NaN

# %%
gt = gt.dropna(axis=0,how='all')

# %%
gt.to_csv('gt_V1.csv')

# %%
business = soup.find('div',class_='content-info-business')

# %%
names = [business.find('h1').text]

# %%
city = ['Guatemala - Guatemala']

# %%
address = [business.find('span').text]

# %%
phone = [soup.find('div',class_='business-buttons').find('a',href=True)['href']]

# %%
web = [soup.find('div',class_='business-buttons').find_all('a',href=True)[2]['href']]

# %%
description = [soup.find('div',class_='info-description').text.strip().split('Sobre la empresa\n')[1].strip()]

# %%
category = [soup.find('div',class_='business-categories').text.strip().split('Listado en: \n\n')[1].strip()]

# %%
pd.DataFrame(zip(names, city, address,phone,web,description,category),
                              columns=['names','city','address','phone','web','description','category'])
# Out:
#         names                   city  \
# 0  Fight Club  Guatemala - Guatemala
#
#                                       address                 phone  \
# 0  24 ave 47-64 zona 12 Prados de Monte Maria  tel:(5025) 4522-0530
#
#                                                  web  \
# 0  https://directorio.guatemala.com/listing_repor...
#
#                                          description  \
# 0  La cualidad dual de Fight Club Guatemala le de...
#
#                                             category
# 0  Artes Marciales\n                             ...
